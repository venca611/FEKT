# %% [markdown]
# # 1 Základní zákony elektrických obvodů a jejich aplikace

# %% [markdown]
# OHMŮV ZÁKON

# %%
import SchemDraw
import SchemDraw.elements as elm
#import matplotlib.pyplot as plt
#plt.xkcd()
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

d = SchemDraw.Drawing()
R = d.add(elm.RBox(botlabel = '$R$'))
d.labelI(R, '$U$')
d.labelI_inline(R, botlabel = '$I$')

d.draw()

# %% [markdown]
# $U = R\cdot I$
